# %%
# Load libraries
import pandas as pd
import json
import numpy as py

# Initialize variables
fileInput='purchase_data.json'

# Open input file, read into fram
pdframePurchaseData = pd.read_json(fileInput)

# Unique players
UniquePlayerCount = len(pdframePurchaseData.groupby('SN').nunique())
pdframeOutput = pd.DataFrame(data={'Total Players':{0: UniquePlayerCount}})
pdframeOutput

# Purchase Analysis (Total)
UniqueItems=len(pdframePurchaseData.groupby('Item ID').nunique())
AvgPurchasePrice=pdframePurchaseData['Price'].mean()
TotalNumberPurchases=len(pdframePurchaseData)
TotalRevenue=pdframePurchaseData['Price'].sum()
pdfOutput = pd.DataFrame(data={'Number of Unique Items':{0: UniqueItems},
                                  'Average Price':{0:AvgPurchasePrice},
                                  'Number of Purchases' :{0: TotalNumberPurchases},
                                  'Total Revenue':{0: TotalRevenue}})
pdfOutput

# Gender demographics
pdfOutput2=pdframePurchaseData.groupby('Gender', as_index=True).agg({'SN': pd.Series.nunique})
pdfOutput2['Pct'] = pdfOutput2['SN'] / UniquePlayerCount * 100
pdfOutput2.columns = ['Unique Players', 'Pct']
print(pdfOutput2)
print("")

# Purchasing analysis (gender)
pdfOutput3=pdframePurchaseData.groupby('Gender', as_index=True).agg({'Item Name': 'count','Price': 'mean'})
pdfOutput3['Total Purchase Value'] = pdfOutput3['Price'] * pdfOutput3['Item Name']
pdfOutput3.columns = ['Purchases', 'Avg Price', 'Total Purchase Value']
print(pdfOutput3)
print("")

# Age demographics
bins = [0, 10, 14, 18, 22, 26, 30, 34, 38]
group_names = ['<10', '11-14', '15-18', '19-22', '23-26', '27-30', '31-34', '>35']
pdfBinned= pdframePurchaseData[0:len(pdframePurchaseData)].copy()
categories = pd.cut(pdfBinned['Age'], bins, labels=group_names)
pdfBinned['Ages'] = pd.cut(pdfBinned['Age'], bins, labels=group_names)
pdfBinned['agesBinned'] = pd.cut(pdfBinned['Age'], bins)
pdfOutput4=pdfBinned.groupby('Ages', as_index=True).agg({'Item Name': 'count','Price': 'mean'})
pdfOutput4['Total Purchase Value'] = pdfOutput4['Price'] * pdfOutput4['Item Name']
pdfOutput4.columns = ['Purchases', 'Avg Price', 'Total Purchase Value']
print(pdfOutput4)
print("")

# Top spenders
pdfOutput5=pdframePurchaseData.groupby('SN', as_index=True).agg({'Item Name': 'count','Price': 'mean'})
pdfOutput5['Total Purchase Value'] = pdfOutput5['Price'] * pdfOutput5['Item Name']
pdfOutput5.columns = ['Purchases', 'Avg Price', 'Total Purchase Value']
print(pdfOutput5.sort_values('Total Purchase Value', ascending=False).head(5))
print("")

# Most popular items
pdfOutput6=pdframePurchaseData.groupby(['Item ID','Item Name','Price'], as_index=True).agg({'Item ID': 'count','Price': 'sum'})
pdfOutput6.columns = ['Purchases', 'Total PV']
cols = pdfOutput6.columns.tolist()
print(pdfOutput6.sort_values('Purchases', ascending=False).head(5))
print("")

# Most profitable items
print(pdfOutput6.sort_values('Total PV', ascending=False).head(5))
# Out:
#    Total Players
# 0            573
#
#    Average Price  Number of Purchases  Number of Unique Items  Total Revenue
# 0       2.931192                  780                     183        2286.33
#
#                        Unique Players        Pct
# Gender
# Female                            100  17.452007
# Male                              465  81.151832
# Other / Non-Disclosed               8   1.396161
#
#                        Purchases  Avg Price  Total Purchase Value
# Gender
# Female                       136   2.815515                382.91
# Male                         633   2.950521               1867.68
# Other / Non-Disclosed         11   3.249091                 35.74
#
#        Purchases  Avg Price  Total Purchase Value
# Ages
# <10           32   3.019375                 96.62
# 11-14         31   2.702903                 83.79
# 15-18        111   2.876757                319.32
# 19-22        231   2.927273                676.20
# 23-26        207   2.937295                608.02
# 27-30         63   2.983968                187.99
# 31-34         46   3.070435                141.24
# >35           37   2.812432                104.06
#
#              Purchases  Avg Price  Total Purchase Value
# SN
# Undirrala66          5   3.412000                 17.06
# Saedue76             4   3.390000                 13.56
# Mindimnya67          4   3.185000                 12.74
# Haellysu29           3   4.243333                 12.73
# Eoda93               3   3.860000                 11.58
#
#                                                     Purchases  Total PV
# Item ID Item Name                            Price
# 39      Betrayal, Whisper of Grieving Widows 2.35          11     25.85
# 84      Arcane Gem                           2.23          11     24.53
# 31      Trickster                            2.07           9     18.63
# 175     Woeful Adamantite Claymore           1.24           9     11.16
# 13      Serenity                             1.49           9     13.41
#
#                                           Purchases  Total PV
# Item ID Item Name                  Price
# 34      Retribution Axe            4.14           9     37.26
# 115     Spectral Diamond Doomblade 4.25           7     29.75
# 32      Orenmir                    4.95           6     29.70
# 103     Singed Scalpel             4.87           6     29.22
# 107     Splitter, Foe Of Subtlety  3.61           8     28.88

# %%
pdfOutput6
# Out:
#                                                             Purchases  \
# Item ID Item Name                                    Price
# 0       Splinter                                     1.82           1
# 1       Crucifer                                     2.28           4
# 2       Verdict                                      3.40           1
# 3       Phantomlight                                 1.79           1
# 4       Bloodlord's Fetish                           2.28           1
# 5       Putrid Fan                                   1.32           3
# 6       Rusty Skull                                  1.20           3
# 7       Thorn, Satchel of Dark Souls                 4.51           6
# 8       Purgatory, Gem of Regret                     3.91           6
# 9       Thorn, Conqueror of the Corrupted            2.04           2
# 10      Sleepwalker                                  1.73           6
# 11      Brimstone                                    2.52           7
# 12      Dawne                                        4.30           5
# 13      Serenity                                     1.49           9
# 14      Possessed Core                               1.59           5
# 15      Soul Infused Crystal                         1.03           6
# 16      Restored Bauble                              3.11           4
# 17      Lazarus, Terror of the Earth                 3.47           3
# 18      Torchlight, Bond of Storms                   1.77           7
# 19      Pursuit, Cudgel of Necromancy                3.98           2
# 20      Netherbane                                   1.48           4
# 21      Souleater                                    3.27           3
# 22      Amnesia                                      3.57           6
# 23      Crucifer                                     2.77           4
# 24      Warped Fetish                                2.41           2
# 25      Hero Cane                                    1.03           4
# 26      Unholy Wand                                  1.88           4
# 27      Riddle, Tribute of Ended Dreams              3.96           4
# 28      Flux, Destroyer of Due Diligence             3.04           1
# 29      Chaos, Ender of the End                      3.79           3
# ...                                                               ...
# 154     Feral Katana                                 2.19           7
# 155     War-Forged Gold Deflector                    3.73           3
# 156     Soul-Forged Steel Shortsword                 1.16           1
# 157     Spada, Etcher of Hatred                      2.21           4
# 158     Darkheart, Butcher of the Champion           3.56           7
# 159     Oathbreaker, Spellblade of Trials            3.01           5
# 160     Azurewrath                                   2.22           5
# 161     Devine                                       1.45           5
# 162     Abyssal Shard                                2.04           3
# 163     Thunderfury Scimitar                         3.02           3
# 164     Exiled Doomblade                             1.92           1
# 165     Bone Crushing Silver Skewer                  3.37           3
# 166     Thirsty Iron Reaver                          4.25           3
# 167     Malice, Legacy of the Queen                  2.38           2
# 168     Sun Strike, Jaws of Twisted Visions          2.64           1
# 169     Interrogator, Blood Blade of the Queen       3.32           4
# 170     Shadowsteel                                  1.98           5
# 171     Scalpel                                      3.62           5
# 172     Blade of the Grave                           1.69           7
# 173     Stormfury Longsword                          4.83           5
# 174     Primitive Blade                              2.46           5
# 175     Woeful Adamantite Claymore                   1.24           9
# 176     Relentless Iron Skewer                       2.97           4
# 177     Winterthorn, Defender of Shifting Worlds     4.89           4
# 178     Oathbreaker, Last Hope of the Breaking Storm 2.41           2
# 179     Wolf, Promise of the Moonwalker              1.88           7
# 180     Stormcaller                                  2.78           5
# 181     Reaper's Toll                                4.56           3
# 182     Toothpick                                    3.48           5
# 183     Dragon's Greatsword                          2.36           5
#
#                                                             Total PV
# Item ID Item Name                                    Price
# 0       Splinter                                     1.82       1.82
# 1       Crucifer                                     2.28       9.12
# 2       Verdict                                      3.40       3.40
# 3       Phantomlight                                 1.79       1.79
# 4       Bloodlord's Fetish                           2.28       2.28
# 5       Putrid Fan                                   1.32       3.96
# 6       Rusty Skull                                  1.20       3.60
# 7       Thorn, Satchel of Dark Souls                 4.51      27.06
# 8       Purgatory, Gem of Regret                     3.91      23.46
# 9       Thorn, Conqueror of the Corrupted            2.04       4.08
# 10      Sleepwalker                                  1.73      10.38
# 11      Brimstone                                    2.52      17.64
# 12      Dawne                                        4.30      21.50
# 13      Serenity                                     1.49      13.41
# 14      Possessed Core                               1.59       7.95
# 15      Soul Infused Crystal                         1.03       6.18
# 16      Restored Bauble                              3.11      12.44
# 17      Lazarus, Terror of the Earth                 3.47      10.41
# 18      Torchlight, Bond of Storms                   1.77      12.39
# 19      Pursuit, Cudgel of Necromancy                3.98       7.96
# 20      Netherbane                                   1.48       5.92
# 21      Souleater                                    3.27       9.81
# 22      Amnesia                                      3.57      21.42
# 23      Crucifer                                     2.77      11.08
# 24      Warped Fetish                                2.41       4.82
# 25      Hero Cane                                    1.03       4.12
# 26      Unholy Wand                                  1.88       7.52
# 27      Riddle, Tribute of Ended Dreams              3.96      15.84
# 28      Flux, Destroyer of Due Diligence             3.04       3.04
# 29      Chaos, Ender of the End                      3.79      11.37
# ...                                                              ...
# 154     Feral Katana                                 2.19      15.33
# 155     War-Forged Gold Deflector                    3.73      11.19
# 156     Soul-Forged Steel Shortsword                 1.16       1.16
# 157     Spada, Etcher of Hatred                      2.21       8.84
# 158     Darkheart, Butcher of the Champion           3.56      24.92
# 159     Oathbreaker, Spellblade of Trials            3.01      15.05
# 160     Azurewrath                                   2.22      11.10
# 161     Devine                                       1.45       7.25
# 162     Abyssal Shard                                2.04       6.12
# 163     Thunderfury Scimitar                         3.02       9.06
# 164     Exiled Doomblade                             1.92       1.92
# 165     Bone Crushing Silver Skewer                  3.37      10.11
# 166     Thirsty Iron Reaver                          4.25      12.75
# 167     Malice, Legacy of the Queen                  2.38       4.76
# 168     Sun Strike, Jaws of Twisted Visions          2.64       2.64
# 169     Interrogator, Blood Blade of the Queen       3.32      13.28
# 170     Shadowsteel                                  1.98       9.90
# 171     Scalpel                                      3.62      18.10
# 172     Blade of the Grave                           1.69      11.83
# 173     Stormfury Longsword                          4.83      24.15
# 174     Primitive Blade                              2.46      12.30
# 175     Woeful Adamantite Claymore                   1.24      11.16
# 176     Relentless Iron Skewer                       2.97      11.88
# 177     Winterthorn, Defender of Shifting Worlds     4.89      19.56
# 178     Oathbreaker, Last Hope of the Breaking Storm 2.41       4.82
# 179     Wolf, Promise of the Moonwalker              1.88      13.16
# 180     Stormcaller                                  2.78      13.90
# 181     Reaper's Toll                                4.56      13.68
# 182     Toothpick                                    3.48      17.40
# 183     Dragon's Greatsword                          2.36      11.80
#
# [183 rows x 2 columns]
